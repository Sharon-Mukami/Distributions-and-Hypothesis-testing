# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharon-Mukami/Distributions-and-Hypothesis-testing/blob/main/Phase2_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %%
conn=sqlite3.connect('/content/im.db')
q1="""SELECT *
FROM movie_basics
JOIN movie_ratings
USING(movie_id)
"""
df1=pd.read_sql(q1,conn)
df1.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
df1.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
movies_gross=pd.read_csv('/content/bom.movie_gross.csv')
movies_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movies_gross.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
movies_info=pd.read_csv('/content/rt.movie_info.tsv',sep='\t', on_bad_lines='skip', encoding='ISO-8859-1')
movies_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
movies_info.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
movies_reviews=pd.read_csv('/content/rt.reviews.tsv',sep='\t', on_bad_lines='skip', encoding='ISO-8859-1')
movies_reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
movies_reviews.columns
# Out:
# Index(['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')

# %%
movies=pd.read_csv('/content/tmdb.movies.csv',index_col=0)
movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# ...

# %%
movies.columns
# Out:
# Index(['genre_ids', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
Movies_budgets=pd.read_csv('/content/tn.movie_budgets.csv')
Movies_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
Movies_budgets.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %% [markdown]
# ###From the datasets above:
# 1.The first data set is a joined sql dataset of **movie basics and movie ratings.** It has got the following columns : **('movie_id',  'primary_title',  'original_title',
#  'start_year',  'runtime_minutes',  'genres', 'averagerating',  'numvotes')**
#
# 2.The second dataset is a csv file converted into a dataframe **Movies Gross** with the following columns : **('title', 'studio', 'domestic_gross', 'foreign_gross', 'year')**
#
# 3.The third dataset is a tsv file converted into a dataframe **Movies Info** with the following columns : **('id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio')**
#
# 4.The forth dataset is a tsv file converted into a dataframe **Movies reviews** with the following columns : **('id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date')**
#
# 5.The fifth dataset is a csv file converted into a dataframe **Movies** with the following columns : **('genre_ids', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'title', 'vote_average', 'vote_count')**
#
# 6.The sixth dataset is a csv file converted into a dataframe **Movies Budgets** with the following columns : **('id', 'release_date', 'movie', 'production_budget', 'domestic_gross', 'worldwide_gross')**
